# %%
import cv2

# %%
import skimage

# %%
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
#open/show/shave an Image

# %%
img1=plt.imread('robo.jpg')
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
img2=cv2.imread('robo2.jpg')
cv2.imshow('Image',img2)
cv2.waitKey(1)
# Out:
# -1

# %%
img2=cv2.imread('robo2.jpg')
cv2.imshow('Image',img2)
cv2.waitKey(0)
# Out:
# -1

# %%
img3=skimage.io.imread('robo2.jpg')
skimage.io.imshow(img3)

# %%
img3.shape,  img1.shape,
# Out:
# ((172, 293, 3), (183, 275, 3))

# %%
import numpy as np 
r1=np.random.randint(0,255,(500,500,3))
plt.imshow(r1)

# %%
r2=np.random.randint(0,255,(50,50))
plt.imshow(r2,cmap='gray')

# %%
img=np.ones((50,50,3),dtype='uint8')*255
img[:25,:25,1:]= 0 #    img[:25,:25,1:]*0
img[25:,:25,:2]=0 #     img[25:,:25,:2]*0
img[:25,25:,::2]= 0 #    img[:25,25:,::2]*0
img[25:,25:,2:]= 0 #       img[25:,25:,2:]*0



plt.imshow(img)

# %%
plt.imsave('squarebox.png',img)

# %%
skimage.io.imsave('squarebox.png',img)

# %%
cv2.imwrite('squarebox.png',img[:,:,::-1])
# Out:
# True

# %%
# Out:
#   Cell In[20], line 1
#     ..
#     ^
# SyntaxError: invalid syntax
